# %%
from numpy import *
import time as time
import sys
import matplotlib.pyplot as plt

#polyorder =5
#n=10
tol=1e-10
ZERO =1.0E-10

def fun_6D(x1,y1,z1,x2,y2,z2):
   # funcarray=zeros(n)
    alpha=2
    func_val=0
    
    r1=sqrt(x1**2+y1**2+z1**2)
    #plt.plot(exp(-4*r1))
   # plt.show
    r2=sqrt(x2**2+y2**2+z2**2)
    r1r2=sqrt((x1-x2)**2+(y1-y2)**2+(z1-z2)**2)
    if (r1r2>=tol):
        func_val=exp(-2*alpha*(r1+r2))/r1r2
    #    funcarray=funcarray.append()
        # xscale=np.linspace(0,10,50)
        
        return(func_val)
    else:
        return 0
    #plt.plot(func_val)
    #plt.show()
    #print("func_val")
    #print(func_val)
    

#x=zeros(n)
#w=zeros(n)
def gauleg(x1, x2, x, w, n):
    itr=0
    m  = (n + 1)/2                         
    xm = (x2 + x1)/2
    xl = (x2 - x1)/2
      
    for i in range(int(ceil(m))): 
        # removed ceil from ceil (m)
        z = cos(pi*(i+0.75)/(n+0.5))
        z1 = 0
        while(abs(z-z1)>ZERO):
            p1 = 1.0
            p2 = 0.0
            for j in range(n):
                p3 = p2
                p2 = p1
                p1 = ((2.0*j+1.0)*z*p2 -j*p3)/(j+1.0)
                
            pp = n*(z*p1-p2)/(z*z-1.0)
            z1 = z
            z = z1 - p1/pp
            
        x[i] = xm - xl*z
        x[n-1-i] = xm + xl*z
        w[i] = 2.0*xl/((1.0 - z*z)*pp*pp)
        w[n-1-i] = w[i]
    print(x,w)
    return x, w
    
#writing time values to file 
outf = open('gauss legendre.txt', 'w+')
outf.write("n \t a\t  b\t  legrendre_resutlt\t exact_result\t realtive error\t exe time_legrendre\n")
outf.close()
def main():
    a=-1
    b=1
    int_gauss = 0
    x=zeros(n)
    w=zeros(n)
    r=zeros(n)
    u=zeros(n)
    gauleg(a,b,r,u,n)

    #def main():

    #maxit=[10,14,18]
    #for i in range(0,len(maxit)):
    #n =maxit[i]
    #n=10
    #print("n",n)
    

    exact_integral=5*3.14*3.14/256
    legrendre_start_time=time.time()
    for i1 in range (0,n) :
        for i2 in range (0,n) :
            for i3 in range (0,n) :
                for j1 in range (0,n) :
                    for j2 in range (0,n):
                        for j3 in range (0,n):
                            temp = 1.0
                            temp= temp *fun_6D(r[i1],r[i2],r[i3],r[j1],r[j2],r[j3])
                            #print("func6d array", len(r))
                            #temp= fun_6D(r[i1],r[i2],r[i3],r[j1],r[j2],r[j3]) *u[i1]*u[i2]*u[i3]*u[j1]*u[j2]*u[j3]
                            temp = temp * u[i1]*u[i2]*u[i3]*u[j1]*u[j2]*u[j3]
                            int_gauss = temp+int_gauss
                            #int_gauss = temp
    print("int_gauss")
    print(int_gauss)    
    legrendre_finish_time=time.time()
    legrendre_exe_time=legrendre_finish_time- legrendre_start_time
    print("legrendre exe time", legrendre_exe_time)
    #a=-5;
    #b=5;

    relatative_error = abs(int_gauss - exact_integral)/exact_integral
    print("exact integral")
    print(exact_integral)

    print("relatative_error")
    print(relatative_error)

    outf=open('gauss legendre.txt', 'a')
    outf.write(str(n))
    outf.write("\t")
    outf.write(str(a))
    outf.write("\t")
    outf.write(str(b))
    outf.write("\t")
    # outf.write(str(int_gauss))
    outf.write("{:.6f}".format(int_gauss))
    outf.write("\t")
    outf.write("{:.6f}".format(exact_integral))
    outf.write("\t")
    outf.write("{:.4f}".format(relatative_error))
    outf.write("\t")
    outf.write("{:.6f}".format(legrendre_exe_time))
    outf.write("\n")
    #print(i)
    outf.close()

for i in range (10,20,4):
    n=i
    if __name__=="__main__":
        main()
# Out:
# [-0.97390653 -0.86506337 -0.67940957 -0.43339539 -0.14887434  0.14887434
#   0.43339539  0.67940957  0.86506337  0.97390653] [0.06667134 0.14945135 0.21908636 0.26926672 0.29552422 0.29552422
#  0.26926672 0.21908636 0.14945135 0.06667134]
# int_gauss
# 0.1510925656693799
# legrendre exe time 9.77884316444397
# exact integral
# 0.1925703125
# relatative_error
# 0.2153901413574333
# [-0.98628381 -0.92843488 -0.82720132 -0.6872929  -0.51524864 -0.31911237
#  -0.10805495  0.10805495  0.31911237  0.51524864  0.6872929   0.82720132
#   0.92843488  0.98628381] [0.03511946 0.08015809 0.12151857 0.15720317 0.1855384  0.20519846
#  0.21526385 0.21526385 0.20519846 0.1855384  0.15720317 0.12151857
#  0.08015809 0.03511946]
# int_gauss
# 0.15793841103466869
# legrendre exe time 73.48151683807373
# exact integral
# 0.1925703125
# relatative_error
# 0.17984029321929526
# [-0.99156517 -0.95582395 -0.89260247 -0.80370496 -0.69168704 -0.55977083
#  -0.41175116 -0.25188623 -0.08477501  0.08477501  0.25188623  0.41175116
#   0.55977083  0.69168704  0.80370496  0.89260247  0.95582395  0.99156517] [0.02161601 0.04971455 0.07642573 0.10094204 0.12255521 0.14064291
#  0.15468468 0.16427648 0.16914238 0.16914238 0.16427648 0.15468468
#  0.14064291 0.12255521 0.10094204 0.07642573 0.04971455 0.02161601]
# int_gauss
# 0.16064806843305934
# legrendre exe time 333.3005828857422
# exact integral
# 0.1925703125
# relatative_error
# 0.1657692904608059
