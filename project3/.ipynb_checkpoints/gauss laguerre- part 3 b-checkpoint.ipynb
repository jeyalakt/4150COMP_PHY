# %%
from numpy import *
import time as time
import sys
import matplotlib.pyplot as plt

                    
                       
def Integrand(u1,theta1,phi1, u2,theta2, phi2) :
    #fvalue=0
    """
    print("u1",u1)
    print("u2",u2)
    print("theta1",theta1)
    print("theta2",theta2)
    print("phi1",phi1)
    print("phi2",phi2)
    """
    cos_val = ( (cos(theta1)*cos(theta2)) + sin(theta1)*sin(theta2)*cos(phi1-phi2))
    #print("cos_val",cos_val)
    r1r2=sqrt(abs((u1*u1) + (u2*u2) - (2.0*u1*u2*cos_val)))
   # print("r1r2",r1r2)
    #print("r1r2",r1r2)
    epsil = 1.0E-7
    if (r1r2 <= epsil):
        return 0
    else:
        fvalue = u1*u1*u2*u2*sin(theta1)*sin(theta2)* exp(-3*(u1+u2))/r1r2
        #fvalue = exp(-3*(u1+u2))*sin(theta1)*sin(theta2)/(4**5)*r1r2
        #fvalue = exp(-3*(u1+u2))*sin(theta1)*sin(theta2)/(4**5)*r1r2"
        #print("fvalue",fvalue)
        return fvalue

def gauleg(x1, x2, x, w, n):
    itr=0
    ZERO =1.0E-10
    m  = (n + 1)/2                         
    xm =  (0.5 * (x2 + x1))
   # print(xm)
    xl =  (0.5 * (x2 - x1))
    #print(xl)
      
    for i in range(0,int (ceil(m))): 
        z = cos(pi*(i+0.75)/(n+0.5))
        z1 = 0
        while(abs(z-z1)>ZERO):
            p1 = 1.0
            p2 = 0.0
            for j in range(n):
                p3 = p2
                p2 = p1
                p1 = ((2.0*j+1.0)*z*p2 -j*p3)/(j+1.0)
                
            pp = n*(z*p1-p2)/(z*z-1.0)
            z1 = z
            z = z1 - p1/pp
            
        x[i] = xm - xl*z
        x[n-1-i] = xm + xl*z
        w[i] = 2.0*xl/((1.0 - z*z)*pp*pp)
        w[n-1-i] = w[i]
    #print("legrende",x,w)
    return x, w
    

def  gauss_laguerre( x,w, n, alf):
    #tol=1e-10
    ZERO =1.0E-10
    EPS =1.0E-8
    MAXIT=10
    pi = 3.14159265359
    MAXIT=10
    z1=0
    #print("n",n)
    for i in range(1,n+1):
        
        if (i==1):
            z=(1.0+alf)*(3.0+0.92*alf)/(1.0+2.4*n+1.8*alf)
            #print("z",z)
        elif(i==2):
            z += (15.0+6.25*alf)/(1.0+0.9*alf+2.5*n)
            #print("z",z)
        else:
            ai=i-2
            z += ((1.0+2.55*ai)/(1.9*ai)+1.26*ai*alf/(1.0+3.5*ai))*(z-x[i-2])/(1.0+0.3*alf)
            #print("z",z)
        for its in range (1,MAXIT+1):
            while(abs(z-z1)>ZERO):
                p1=1.0
                p2=0.0
                for j in range(1,n+1):
                    p3=p2
                    p2=p1
                    p1=((2*j-1+alf-z)*p2-(j-1+alf)*p3)/j

                pp=(n*p1-(n+alf)*p2)/z
                z1=z
                z=z1-p1/pp
            x[i]=z
            #print("xi",x[i])
            w[i] = -exp(gammln(alf+n)-gammln(double(n)))/(pp*n*p2)
    #print("laguerre",x,w)
    return x, w
           
def  gammln(xx):
   # cof=zeros(6)
    cof=[76.18009172947146,-86.50532032941677,
                24.01409824083091,-1.231739572450155,
                0.1208650973866179e-2,-0.5395239384953e-5]
    #print ("coeff", cof)
    y=x=xx
    tmp=x+5.5
    tmp -= (x+0.5)*log(tmp)
    ser=1.000000000190015
    for j in range(0,6) :
        ser += cof[j]/++y
        out=-tmp+log(2.5066282746310005*ser/x)
       # print ("out", out)
        return out

outf = open('gauss lagaurre.txt', 'w+')
outf.write("n \t lagaurre_resutlt\t exact_result\t realtive error\t exe time_lagaurre\n")
outf.close()
  
def main():
    #print(Integrand(-4, 5, 4,4, 3, -2)) 
    
    #print(Integrand(-4,2,4,3,5,-2)) 
    
    #n=4
    tol=1e-10
    ZERO =1.0E-10
    EPS =1.0E-8
    MAXIT=10
    pi = 3.14159265359
    int_gauss_laguerre = 0.0;
    exact_integral = 5*pi*pi/256;
    temp=0
    x=zeros(n)
    #print("size",len(x))
    #print("n",n)
    w=zeros(n)
   # t1=zeros(n)
    itr=0
    laguerre_start_time=time.time()
    rg1=zeros(n+1)
    #print("n laguere",n)
    #print("size rg1",len(rg1))
    wg1=zeros(n+1)
    gauss_laguerre(rg1,wg1,n,0.0)
    print(" laguerrerg1 wg1 ",rg1,wg1)

    theta=zeros(n)
    w1=zeros(n)
    gauleg(0, pi, theta, w1, n)
    #theta=x
    #w1=w
    print(" leg theta  ",theta,w1)
    phi=zeros(n)
    w2=zeros(n)
    gauleg(0.0, 2*pi, phi, w2, n)
    print(" leg phi ",phi,w2)
    #phi=x
    #w2=w

    #print("lag, legtheta,legphi",w1, w2, wg1)
    #print ("wg befor loop",wg1)
    for i in range(1,n+1):
        for k in range(0,n):
            for m in range(0,n):
                for j in range(1,n+1):
                    for l in range(0,n):
                        for m2 in range (0,n) :
                            tot_wt=wg1[i]*wg1[j]*w1[k]*w1[l]*w2[m]*w2[m2]
                            #print(tot_wt)
                            temp=Integrand(rg1[i],theta[k],phi[m],rg1[j],theta[l],phi[m2])
                            int_gauss_laguerre += temp*tot_wt
                            #print("temp",temp)
    print("int_gauss _laguerre ")
    print(int_gauss_laguerre)    
    laguerre_finish_time=time.time()
    laguarre_exe_time=laguerre_finish_time- laguerre_start_time
    print("laguarre exe time", laguarre_exe_time)
    relatative_error = abs(int_gauss_laguerre - exact_integral)/exact_integral
    print("exact integral")
    print(exact_integral)

    print("relatative_error")
    print(relatative_error)

    outf=open('gauss lagaurre.txt', 'a')
    outf.write(str(n))
    outf.write("\t")
   # outf.write(str(a))
    #outf.write("\t")
    #outf.write(str(b))
    #outf.write("\t")
    outf.write("{:.6f}".format(int_gauss_laguerre))
    outf.write("\t")
    outf.write("{:.6f}".format(exact_integral))
    outf.write("\t")
    outf.write("{:.6f}".format(relatative_error))
    outf.write("\t")
    outf.write("{:.6f}".format(laguarre_exe_time))
    outf.write("\n")
    outf.close()

for i in range (10, 25 ,5 ):
    n=i
    if __name__=="__main__":
        main()
# Out:
#  laguerrerg1 wg1  [ 0.          0.13779347  0.72945455  1.8083429   3.4014337   5.55249614
#   8.33015275 11.84378584 16.27925783 21.99658581 29.92069701] [0.00000000e+00 3.08441115e-01 4.01119929e-01 2.18068288e-01
#  6.20874561e-02 9.50151698e-03 7.53008389e-04 2.82592335e-05
#  4.24931398e-07 1.83956482e-09 9.91182722e-13]
#  leg theta   [0.04098753 0.21195797 0.50358227 0.89002043 1.33694506 1.80464759
#  2.25157222 2.63801038 2.92963469 3.10060512] [0.1047271  0.23475763 0.34414005 0.42296317 0.46420837 0.46420837
#  0.42296317 0.34414005 0.23475763 0.1047271 ]
#  leg phi  [0.08197506 0.42391594 1.00716455 1.78004087 2.67389012 3.60929518
#  4.50314444 5.27602076 5.85926937 6.20121025] [0.20945421 0.46951526 0.68828011 0.84592635 0.92841673 0.92841673
#  0.84592635 0.68828011 0.46951526 0.20945421]
# int_gauss _laguerre
# 0.17708076787482072
# laguarre exe time 3.464733362197876
# exact integral
# 0.1927657109588019
# relatative_error
# 0.081367910329931
#  laguerrerg1 wg1  [ 0.          0.09330781  0.49269174  1.21559541  2.26994953  3.66762272
#   5.42533663  7.56591623 10.12022857 13.13028248 16.65440771 20.7764789
#  25.62389423 31.40751917 38.53068331 48.02608557] [0.00000000e+00 2.18234885e-01 3.42210178e-01 2.63027578e-01
#  1.26425818e-01 4.02068649e-02 8.56387780e-03 1.21243615e-03
#  1.11674392e-04 6.45992676e-06 2.22631691e-07 4.22743038e-09
#  3.92189727e-11 1.45651526e-13 1.48302705e-16 1.60059491e-20]
#  leg theta   [0.01886131 0.09853072 0.23843654 0.43288362 0.67391534 0.95166484
#  1.25476138 1.57079633 1.88683127 2.18992781 2.46767732 2.70870904
#  2.90315611 3.04306193 3.12273135] [0.04830708 0.11053073 0.16832531 0.21923711 0.26117506 0.29242102
#  0.31169545 0.29907831 0.31169545 0.29242102 0.26117506 0.21923711
#  0.16832531 0.11053073 0.04830708]
#  leg phi  [0.03772262 0.19706145 0.47687308 0.86576723 1.34783067 1.90332968
#  2.50952277 3.14159265 3.77366254 4.37985563 4.93535464 5.41741808
#  5.80631222 6.08612386 6.24546269] [0.09661416 0.22106146 0.33665062 0.43847422 0.52235012 0.58484203
#  0.6233909  0.59815662 0.6233909  0.58484203 0.52235012 0.43847422
#  0.33665062 0.22106146 0.09661416]
# int_gauss _laguerre
# 0.18737083167119106
# laguarre exe time 23.81035828590393
# exact integral
# 0.1927657109588019
# relatative_error
# 0.027986716417443363
#  laguerrerg1 wg1  [ 0.          0.07053989  0.37212682  0.9165821   1.70730653  2.74919926
#   4.04892531  5.61517497  7.45901745  9.59439287 12.03880255 14.81429344
#  17.94889552 21.47878824 25.45170279 29.93255463 35.01343424 40.83305706
#  47.61999405 55.81079575 66.52441653] [0.00000000e+00 1.68746801e-01 2.91254362e-01 2.66686103e-01
#  1.66002453e-01 7.48260647e-02 2.49644173e-02 6.20255084e-03
#  1.14496239e-03 1.55741773e-04 1.54014409e-05 1.08648637e-06
#  5.33012091e-08 1.75798118e-09 3.72550240e-11 4.76752925e-13
#  3.37284424e-15 1.15501434e-17 1.53952214e-20 5.28644273e-24
#  1.65645661e-28]
#  leg theta   [0.01079357 0.05659276 0.13786184 0.25271447 0.39846091 0.57168554
#  0.76832832 0.98378018 1.21299115 1.45058875 1.69100391 1.92860151
#  2.15781248 2.37326434 2.56990711 2.74313174 2.88887818 3.00373082
#  3.08499989 3.13079908] [0.02766802 0.06377658 0.09844502 0.1308108  0.16011146 0.18565954
#  0.20685603 0.22320405 0.23432038 0.23994446 0.23994446 0.23432038
#  0.22320405 0.20685603 0.18565954 0.16011146 0.1308108  0.09844502
#  0.06377658 0.02766802]
#  leg phi  [0.02158714 0.11318553 0.27572368 0.50542894 0.79692182 1.14337108
#  1.53665663 1.96756035 2.4259823  2.9011775  3.38200781 3.85720301
#  4.31562496 4.74652867 5.13981422 5.48626349 5.77775637 6.00746163
#  6.16999978 6.26159816] [0.05533604 0.12755315 0.19689005 0.2616216  0.32022292 0.37131907
#  0.41371206 0.44640809 0.46864076 0.47988892 0.47988892 0.46864076
#  0.44640809 0.41371206 0.37131907 0.32022292 0.2616216  0.19689005
#  0.12755315 0.05533604]
# int_gauss _laguerre
# 0.19478557819905581
# laguarre exe time 136.97187972068787
# exact integral
# 0.1927657109588019
# relatative_error
# 0.010478353386643524
