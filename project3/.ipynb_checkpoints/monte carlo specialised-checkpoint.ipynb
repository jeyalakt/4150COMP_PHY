# %%
from numpy import *
import time as time
import sys
import matplotlib.pyplot as plt
from scipy.stats import uniform
from scipy.stats import expon

# monte carlo brute force method using uniform distribution
tol=1e-10
outf = open('monte carlo brute.txt', 'w+')
outf.write("n \t a\t  b\t  legrendre_resutlt\t exact_result\t realtive error\t sigma\t exe time_legrendre\n")
outf.close()

def func_6D(x1,y1,z1,x2,y2,z2):
    alpha=2
    func_val=0
    r1=sqrt(x1*x1+y1*y1+z1*z1)
    r2=sqrt(x2**2+y2**2+z2**2)
    r1r2=sqrt((x1-x2)**2+(y1-y2)**2+(z1-z2)**2)
    if (r1r2>=tol):
        func_val=exp(-2*alpha*(r1+r2))/r1r2
        return(func_val)
    else:
        return 0    

for i in range (10**5,10**7,10**6):
    n=i
    a=-1
    b=1
    d=6
    int_MC=0
    sum_sigma=0
    sigma=0
    func_res=0
    jacobi_det=(4*acos(-1)**4)*1/16
    #exact_integral=5*3.14*3.14/256
    MC_start_time=time.time()
    for j in range (0,2):
        y =random.uniform(a,b)
        x[j]=0.25 log(1-y)
    for j in rang(2,4)
        y =random.uniform(a,b)
        x[j]=2*cos(-1)*y
    for j in rang(4,6)
        y =random.uniform(a,b)
        x[j]=acos(-1)*y
    
    
    """
    #Function for the CDF of the exponential distribution
def CDFExponential(lamb,x): #lamb = lambda
    if x<=0:
        cdf=0
    else:
        cdf=1-np.exp(-lamb*x)
    return cdf
#Function to compute the mean of the exponential distribution
def MeanExponential(lamb):
    return 1/lamb;
def VarianceExponential(lamb):
return (1/lamb)**2;
    """
    
    
    
    
        #print(x1,y1,z1,x2,y2,z2)
        func_res=func_6D(x1,y1,z1,x2,y2,z2)                     
        int_MC = int_MC+func_res
        # print("int mc",int_MC)
        sum_sigma+=func_res*func_res
    MC_finish_time=time.time()
    MC_exe_time=MC_finish_time- MC_start_time
    #print("MC exe time", MC_exe_time)
    #print("int_MC")
    # print(int_MC)
    int_MC /=  n
    sum_sigma /=  n
    variance = sum_sigma - int_MC*int_MC
    int_MC *= jacobi_det
    sigma = jacobi_det*sqrt(variance/n)
    exact_integral=5*3.14*3.14/256
    relative_error = abs(int_MC-exact_integral)/exact_integral;
    #print("int_MC")
    #print(int_MC)
    
    #print("exact integral")
    #print(exact_integral)

    #print("relatative_error")
    #print(relatative_error)
    
    outf=open('monte carlo brute.txt', 'a')
    outf.write(str(n))
    outf.write("\t")
    outf.write(str(a))
    outf.write("\t")
    outf.write(str(b))
    outf.write("\t")
    outf.write("{:.6f}".format(int_MC))
    outf.write("\t")
    outf.write("{:.6f}".format(exact_integral))
    outf.write("\t")
    outf.write("{:.6f}".format(relatative_error))
    outf.write("\t")
    outf.write("{:.6f}".format(sigma))
    outf.write("\t")
    outf.write("{:.6f}".format(MC_exe_time))
    outf.write("\n")
    outf.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-14d9ccb693b4> in <module>
#      44         z2= random.uniform(a,b)
#      45         #print(x1,y1,z1,x2,y2,z2)
# ---> 46         func_res=func_6D(x1,y1,z1,x2,y2,z2)
#      47         int_MC = int_MC+func_res
#      48         # print("int mc",int_MC)
#
# <ipython-input-4-14d9ccb693b4> in func_6D(x1, y1, z1, x2, y2, z2)
#      15     alpha=2
#      16     func_val=0
# ---> 17     r1=sqrt(x1*x1+y1*y1+z1*z1)
#      18     r2=sqrt(x2**2+y2**2+z2**2)
#      19     r1r2=sqrt((x1-x2)**2+(y1-y2)**2+(z1-z2)**2)
#
# TypeError: unsupported operand type(s) for *: 'rv_frozen' and 'rv_frozen'
