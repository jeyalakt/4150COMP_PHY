# %%
import numpy as np
from scipy import linalg
import time as time
import sys
import matplotlib.pyplot as plt
tol = 1.0e-10


#def gauss_laguerre:
    
#def gauleg:
    
def func_6D(x1,x2,x3,y1,y2,y3):
    alpha=2
    func_val=0
    r1=np.sqrt(x1^2+y1^2+z1^2)
    r2=np-sqrt(x2^2+y2^2+z2^2)
    r1r2=abs_dist(x1,x2,x3,y1,y2,y3)
    if (r1r1>=tol):
        func_val=np.exp(-2*alpha*(r1+r2))/r1r2
        return(func_val)
    print("func_val")
    print(func_val)
    
    

def abs_dist(x1,x2,x3,y1,y2,y3):
    r1r2=np.sqrt((x1-x2)^2+(y1-y2)^2+(z1-z2)^2)
    return r1r2
    print("r1r2")
    print (r1r2)
    
n=10
#A[]=[10,15]
pi=3.14159265359
exact_integral = 5*pi*pi/256 
int_gauss = 0.0
relatative_error = 0.0
calculation_time = 0.0
outfilename = "Gauss_Legendre_table.txt";

 # n = A[l];
#trying the 6D integral with Gauss-Legendre method:
r =np.zeros(n)
u =np.zeros(n)
 # int_gauss = 0.;
 # calculation_time = 0.0;
#Limits of the integral in Cartesian coordinates  a , b
a=-5;
b=5;
gauleg(a, b, r, u, n)
    
    for i1 in range (0,n) :
        for i2 in range (0,n) :
            for i3 in range (0,n) :
                for j1 in range (0,n) :
                    for j2 in range (0,n):
                        for j3 in range (0,n):
                            temp = 1.0
                            temp= temp *func_6D(r[i1],r[i2],r[i3],r[j1],r[j2],r[j3])
                            temp = temp * u[i1]*u[i2]*u[i3]*u[j1]*u[j2]*u[j3]
                            int_gauss = temp+int_gauss
                            return int_gauss
print("int_gauss")
print(int_gauss)
            

relatative_error = np.abs(int_gauss - exact_integral)/exact_integral

print("relatative_error")
print(relatative_error)


The function
def gauleg(x1,x2,x,w,n):
    m  = (n + 1)/2;                             // roots are symmetric in the interval
    xm = 0.5 * (x2 + x1);
    xl = 0.5 * (x2 - x1);
    for i in range (1,m)
        z=cos(pi*(i-0.25)/(n+0.5))
        error =10*tol
        itern=0
        while (error>tol and itern<10):
            p1=1
            p2=0
            for j in range(1,n+1):
                p3=p2
                p2=p1
                p1=((2*j-1)*z*p2-(j-1)*p3)/j
            pp=n*(z*p1-p2)/(z*z-1)
            z1=z
            z=z1-p1/pp
            
#takes the lower and upper limits of integration x1, x2, calculates
#and return the abcissas in x[0,...,n - 1] and the weights in w[0,...,n - 1]
#of length n of the Gauss--Legendre n--point quadrature formulae.
# Out:
# int_gauss
# 0.0
# relatative_error
# 1.0
